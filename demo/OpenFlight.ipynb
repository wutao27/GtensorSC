# %%
push!(LOAD_PATH, "../")
include("../util.jl")
# Out:
# print_tree_word (generic function with 1 method)

# %%
# demo for openFlight data

# para is the parameters for the algorithm here we set ALPHA = 0.8, MIN_NUM = 5, MAX_NUM = 100, PHI = 0.4
para = algPara(0.8, 5, 100,0.4)
P = read_tensor("../data/openFlight/tensor_openflight.txt");

# the return value r is the binary tree for clustering results.
(r,h) = tensor_speclustering(P, para);
# Out:
# -----------calculating #1 cut----------
# 	tensor size 3478 with 160047 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 3478 into 3151 and 327 --
#
# -----------calculating #2 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 2633 with 49839 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 2633 into 2417 and 216 --
#
# -----------calculating #3 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 2391 with 43785 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 2391 into 2245 and 146 --
#
# -----------calculating #4 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 2144 with 35955 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 2144 into 1587 and 557 --
#
# -----------calculating #5 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 1524 with 18177 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 1524 into 1057 and 467 --
#
# -----------calculating #6 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 1021 with 8751 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 1021 into 924 and 97 --
#
# -----------calculating #7 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 918 with 7365 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 918 into 872 and 46 --
#
# -----------calculating #8 cut----------
# 	tensor size 872 with 6699 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 872 into 837 and 35 --
#
# -----------calculating #9 cut----------
# 	tensor size 837 with 6345 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 837 into 790 and 47 --
#
# -----------calculating #10 cut----------
# 	tensor size 790 with 5715 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 790 into 756 and 34 --
#
# -----------calculating #11 cut----------
# 	tensor size 756 with 5343 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 756 into 667 and 89 --
#
# -----------calculating #12 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 665 with 4569 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 665 into 635 and 30 --
#
# -----------calculating #13 cut----------
# 	tensor size 635 with 4275 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 635 into 607 and 28 --
#
# -----------calculating #14 cut----------
# 	tensor size 607 with 4029 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 607 into 547 and 60 --
#
# -----------calculating #15 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 555 with 15816 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 555 into 352 and 203 --
#
# -----------calculating #16 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 546 with 3603 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 546 into 470 and 76 --
#
# -----------calculating #17 cut----------
# 	tensor size 470 with 2763 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 470 into 448 and 22 --
#
# -----------calculating #18 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 466 with 8634 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 466 into 249 and 217 --
#
# -----------calculating #19 cut----------
# 	tensor size 448 with 2517 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 448 into 434 and 14 --
#
# -----------calculating #20 cut----------
# 	tensor size 434 with 2421 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 434 into 387 and 47 --
#
# -----------calculating #21 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 386 with 1989 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 386 into 359 and 27 --
#
# -----------calculating #22 cut----------
# 	tensor size 359 with 1779 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 359 into 340 and 19 --
#
# -----------calculating #23 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 344 with 5988 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 344 into 231 and 113 --
#
# -----------calculating #24 cut----------
# 	tensor size 340 with 1623 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 340 into 320 and 20 --
#
# -----------calculating #25 cut----------
# 	tensor size 327 with 29196 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 327 into 174 and 153 --
#
# -----------calculating #26 cut----------
# 	tensor size 320 with 1491 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 320 into 309 and 11 --
#
# -----------calculating #27 cut----------
# 	tensor size 309 with 1419 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 309 into 297 and 12 --
#
# -----------calculating #28 cut----------
# 	tensor size 297 with 1353 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 297 into 284 and 13 --
#
# -----------calculating #29 cut----------
# 	tensor size 284 with 1245 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 284 into 270 and 14 --
#
# -----------calculating #30 cut----------
# 	tensor size 270 with 1161 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 270 into 248 and 22 --
#
# -----------calculating #31 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 100 with 534 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 100 into 86 and 14 --
#
# -----------calculating #32 cut----------
# 	tensor size 248 with 1023 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 248 into 240 and 8 --
#
# -----------calculating #33 cut----------
# 	tensor size 240 with 957 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 240 into 220 and 20 --
#
# -----------calculating #34 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 51 with 210 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 51 into 44 and 7 --
#
# -----------calculating #35 cut----------
# 	tensor size 220 with 855 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 220 into 211 and 9 --
#
# -----------calculating #36 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 39 with 168 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 39 into 28 and 11 --
#
# -----------calculating #37 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 214 with 5544 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 214 into 133 and 81 --
#
# -----------calculating #38 cut----------
# 	tensor size 211 with 783 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 211 into 200 and 11 --
#
# -----------calculating #39 cut----------
# 	tensor size 203 with 8634 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 203 into 127 and 76 --
#
# -----------calculating #40 cut----------
# 	tensor size 200 with 717 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 200 into 186 and 14 --
#
# -----------calculating #41 cut----------
# 	tensor size 186 with 657 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 186 into 178 and 8 --
#
# -----------calculating #42 cut----------
# 	tensor size 178 with 609 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 178 into 168 and 10 --
#
# -----------calculating #43 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 85 with 648 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6153131160906455) > PHI
#
# -----------calculating #44 cut----------
# 	tensor size 168 with 567 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 168 into 155 and 13 --
#
# -----------calculating #45 cut----------
# 	tensor size 155 with 507 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 155 into 144 and 11 --
#
# -----------calculating #46 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 115 with 1692 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 115 into 59 and 56 --
#
# -----------calculating #47 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 145 with 5178 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 145 into 77 and 68 --
#
# -----------calculating #48 cut----------
# 	tensor size 144 with 453 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 144 into 137 and 7 --
#
# -----------calculating #49 cut----------
# 	tensor size 137 with 423 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 137 into 129 and 8 --
#
# -----------calculating #50 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 43 with 168 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 43 into 37 and 6 --
#
# -----------calculating #51 cut----------
# 	tensor size 129 with 387 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 129 into 121 and 8 --
#
# -----------calculating #52 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 49 with 264 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5836031034821347) > PHI
#
# -----------calculating #53 cut----------
# 	tensor size 121 with 357 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 121 into 108 and 13 --
#
# -----------calculating #54 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 28 with 144 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 28 into 15 and 13 --
#
# -----------calculating #55 cut----------
# 	tensor size 108 with 321 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 108 into 89 and 19 --
#
# -----------calculating #56 cut----------
# 	tensor size 97 with 1218 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6356264911061347) > PHI
#
# -----------calculating #57 cut----------
# 	tensor size 89 with 756 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5912165405464593) > PHI
#
# -----------calculating #58 cut----------
# 	tensor size 89 with 243 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 89 into 83 and 6 --
#
# -----------calculating #59 cut----------
# 	tensor size 86 with 396 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 86 into 65 and 21 --
#
# -----------calculating #60 cut----------
# 	tensor size 83 with 225 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 83 into 78 and 5 --
#
# -----------calculating #61 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 9 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 9 into 6 and 3 --
#
# -----------calculating #62 cut----------
# 	tensor size 78 with 207 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 78 into 57 and 21 --
#
# -----------calculating #63 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 13 with 42 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.710772088327088) > PHI
#
# -----------calculating #64 cut----------
# tensor size smaller than MIN_NUM
#
# -----------calculating #65 cut----------
# 	tensor size 76 with 822 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5320851196708211) > PHI
#
# -----------calculating #66 cut----------
# 	process empty indices in sub-tensor
# tensor size smaller than MIN_NUM
#
# -----------calculating #67 cut----------
# 	tensor size 65 with 246 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 65 into 59 and 6 --
#
# -----------calculating #68 cut----------
# 	tensor size 60 with 402 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 60 into 37 and 23 --
#
# -----------calculating #69 cut----------
# 	tensor size 59 with 192 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 59 into 49 and 10 --
#
# -----------calculating #70 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 17 with 72 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.786560110888658) > PHI
#
# -----------calculating #71 cut----------
# 	tensor size 57 with 147 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 57 into 47 and 10 --
#
# -----------calculating #72 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 8 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6832598792723021) > PHI
#
# -----------calculating #73 cut----------
# 	tensor size 49 with 162 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 49 into 34 and 15 --
#
# -----------calculating #74 cut----------
# 	tensor size 47 with 123 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 47 into 40 and 7 --
#
# -----------calculating #75 cut----------
# 	tensor size 47 with 342 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6247859531538098) > PHI
#
# -----------calculating #76 cut----------
# 	tensor size 47 with 618 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6367744867161746) > PHI
#
# -----------calculating #77 cut----------
# 	tensor size 46 with 654 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6715505248087201) > PHI
#
# -----------calculating #78 cut----------
# 	tensor size 44 with 180 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 44 into 39 and 5 --
#
# -----------calculating #79 cut----------
# 	tensor size 40 with 105 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 40 into 37 and 3 --
#
# -----------calculating #80 cut----------
# 	tensor size 39 with 162 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 39 into 27 and 12 --
#
# -----------calculating #81 cut----------
# 	tensor size 37 with 150 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 37 into 25 and 12 --
#
# -----------calculating #82 cut----------
# 	tensor size 37 with 222 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6237603331216396) > PHI
#
# -----------calculating #83 cut----------
# 	tensor size 37 with 99 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 37 into 33 and 4 --
#
# -----------calculating #84 cut----------
# 	tensor size 35 with 354 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6160607202484867) > PHI
#
# -----------calculating #85 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 32 with 90 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 32 into 28 and 4 --
#
# -----------calculating #86 cut----------
# 	tensor size 34 with 372 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7004242959539861) > PHI
#
# -----------calculating #87 cut----------
# 	tensor size 33 with 87 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 33 into 26 and 7 --
#
# -----------calculating #88 cut----------
# 	tensor size 30 with 282 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6245822823440388) > PHI
#
# -----------calculating #89 cut----------
# 	tensor size 28 with 246 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6706545132224471) > PHI
#
# -----------calculating #90 cut----------
# 	tensor size 28 with 78 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 28 into 18 and 10 --
#
# -----------calculating #91 cut----------
# 	tensor size 28 with 132 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 28 into 17 and 11 --
#
# -----------calculating #92 cut----------
# 	tensor size 27 with 90 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 27 into 18 and 9 --
#
# -----------calculating #93 cut----------
# 	tensor size 27 with 210 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5833629214851395) > PHI
#
# -----------calculating #94 cut----------
# 	tensor size 26 with 63 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 26 into 21 and 5 --
#
# -----------calculating #95 cut----------
# 	tensor size 25 with 90 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 25 into 16 and 9 --
#
# -----------calculating #96 cut----------
# 	tensor size 23 with 168 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.626458586201196) > PHI
#
# -----------calculating #97 cut----------
# 	tensor size 22 with 246 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6988561917142335) > PHI
#
# -----------calculating #98 cut----------
# 	tensor size 22 with 138 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 22 into 14 and 8 --
#
# -----------calculating #99 cut----------
# 	tensor size 21 with 51 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 21 into 18 and 3 --
#
# -----------calculating #100 cut----------
# 	tensor size 21 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 21 into 17 and 4 --
#
# -----------calculating #101 cut----------
# 	tensor size 21 with 144 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 21 into 11 and 10 --
#
# -----------calculating #102 cut----------
# 	tensor size 20 with 132 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6781041045006857) > PHI
#
# -----------calculating #103 cut----------
# 	tensor size 20 with 102 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5486505228939503) > PHI
#
# -----------calculating #104 cut----------
# 	tensor size 19 with 156 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6692088663285023) > PHI
#
# -----------calculating #105 cut----------
# 	tensor size 19 with 78 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 19 into 14 and 5 --
#
# -----------calculating #106 cut----------
# 	tensor size 18 with 54 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 18 into 11 and 7 --
#
# -----------calculating #107 cut----------
# 	tensor size 18 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 18 into 12 and 6 --
#
# -----------calculating #108 cut----------
# 	tensor size 18 with 45 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 18 into 9 and 9 --
#
# -----------calculating #109 cut----------
# 	tensor size 17 with 48 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 17 into 10 and 7 --
#
# -----------calculating #110 cut----------
# 	tensor size 17 with 96 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 17 into 10 and 7 --
#
# -----------calculating #111 cut----------
# 	tensor size 16 with 42 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 16 into 10 and 6 --
#
# -----------calculating #112 cut----------
# 	tensor size 15 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.618346729221539) > PHI
#
# -----------calculating #113 cut----------
# 	tensor size 15 with 66 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6067627157757959) > PHI
#
# -----------calculating #114 cut----------
# 	tensor size 14 with 84 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6848300493628635) > PHI
#
# -----------calculating #115 cut----------
# 	tensor size 14 with 54 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 14 into 10 and 4 --
#
# -----------calculating #116 cut----------
# 	tensor size 14 with 72 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6402956078831599) > PHI
#
# -----------calculating #117 cut----------
# 	tensor size 14 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7067972737998134) > PHI
#
# -----------calculating #118 cut----------
# 	tensor size 14 with 132 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6433103293318224) > PHI
#
# -----------calculating #119 cut----------
# 	tensor size 14 with 96 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.646829724377403) > PHI
#
# -----------calculating #120 cut----------
# 	tensor size 13 with 36 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.40631110107800583) > PHI
#
# -----------calculating #121 cut----------
# 	tensor size 13 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6808748480284671) > PHI
#
# -----------calculating #122 cut----------
# 	tensor size 13 with 108 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6710517227319663) > PHI
#
# -----------calculating #123 cut----------
# 	tensor size 13 with 84 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7185205596148768) > PHI
#
# -----------calculating #124 cut----------
# 	tensor size 12 with 42 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 12 into 9 and 3 --
#
# -----------calculating #125 cut----------
# 	tensor size 12 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6691380180617582) > PHI
#
# -----------calculating #126 cut----------
# 	tensor size 12 with 54 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6884778533982003) > PHI
#
# -----------calculating #127 cut----------
# 	tensor size 12 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7297957282490025) > PHI
#
# -----------calculating #128 cut----------
# 	tensor size 11 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 11 into 7 and 4 --
#
# -----------calculating #129 cut----------
# 	tensor size 11 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6895524553928292) > PHI
#
# -----------calculating #130 cut----------
# 	tensor size 11 with 54 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6731048229695383) > PHI
#
# -----------calculating #131 cut----------
# 	tensor size 11 with 66 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7567026040937626) > PHI
#
# -----------calculating #132 cut----------
# 	tensor size 11 with 72 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7079196147381972) > PHI
#
# -----------calculating #133 cut----------
# 	tensor size 11 with 36 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 11 into 8 and 3 --
#
# -----------calculating #134 cut----------
# 	tensor size 11 with 36 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5941734164217432) > PHI
#
# -----------calculating #135 cut----------
# 	tensor size 10 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 10 into 7 and 3 --
#
# -----------calculating #136 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 8 with 42 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7760933161560942) > PHI
#
# -----------calculating #137 cut----------
# 	tensor size 10 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 10 into 6 and 4 --
#
# -----------calculating #138 cut----------
# 	tensor size 10 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5087565858425479) > PHI
#
# -----------calculating #139 cut----------
# 	tensor size 10 with 42 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6969060267958449) > PHI
#
# -----------calculating #140 cut----------
# 	tensor size 10 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5548957238433424) > PHI
#
# -----------calculating #141 cut----------
# 	tensor size 10 with 36 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7076359159979824) > PHI
#
# -----------calculating #142 cut----------
# 	tensor size 10 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6669189543072812) > PHI
#
# -----------calculating #143 cut----------
# 	tensor size 10 with 60 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7429051711899892) > PHI
#
# -----------calculating #144 cut----------
# 	tensor size 9 with 21 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 9 into 6 and 3 --
#
# -----------calculating #145 cut----------
# 	process empty indices in sub-tensor
# 	tensor size 8 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5320782562446446) > PHI
#
# -----------calculating #146 cut----------
# 	tensor size 9 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7145782944385795) > PHI
#
# -----------calculating #147 cut----------
# 	tensor size 9 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 9 into 6 and 3 --
#
# -----------calculating #148 cut----------
# 	tensor size 9 with 72 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7035029289084329) > PHI
#
# -----------calculating #149 cut----------
# 	tensor size 9 with 48 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7824182563055347) > PHI
#
# -----------calculating #150 cut----------
# 	tensor size 8 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6383377655683865) > PHI
#
# -----------calculating #151 cut----------
# 	tensor size 8 with 36 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.692669423596112) > PHI
#
# -----------calculating #152 cut----------
# 	tensor size 8 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6739902391900285) > PHI
#
# -----------calculating #153 cut----------
# 	tensor size 8 with 48 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7232089891616639) > PHI
#
# -----------calculating #154 cut----------
# 	tensor size 8 with 54 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6586163302085475) > PHI
#
# -----------calculating #155 cut----------
# 	tensor size 8 with 66 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7329288369501846) > PHI
#
# -----------calculating #156 cut----------
# 	tensor size 7 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7339974118164214) > PHI
#
# -----------calculating #157 cut----------
# 	tensor size 7 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 7 into 4 and 3 --
#
# -----------calculating #158 cut----------
# 	tensor size 7 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 7 into 4 and 3 --
#
# -----------calculating #159 cut----------
# 	tensor size 7 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6955892823014663) > PHI
#
# -----------calculating #160 cut----------
# 	tensor size 7 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.5532266536801274) > PHI
#
# -----------calculating #161 cut----------
# 	tensor size 7 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 7 into 4 and 3 --
#
# -----------calculating #162 cut----------
# 	tensor size 7 with 30 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7519839724638787) > PHI
#
# -----------calculating #163 cut----------
# 	tensor size 7 with 24 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7151815859552749) > PHI
#
# -----------calculating #164 cut----------
# 	tensor size 7 with 36 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.745088651342461) > PHI
#
# -----------calculating #165 cut----------
# 	tensor size 6 with 12 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 6 into 3 and 3 --
#
# -----------calculating #166 cut----------
# 	tensor size 6 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7791708672490965) > PHI
#
# -----------calculating #167 cut----------
# 	tensor size 6 with 54 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.8340493131480972) > PHI
#
# -----------calculating #168 cut----------
# 	tensor size 6 with 15 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 6 into 3 and 3 --
#
# -----------calculating #169 cut----------
# 	tensor size 6 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.8012779022062155) > PHI
#
# -----------calculating #170 cut----------
# 	tensor size 6 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7921020656426649) > PHI
#
# -----------calculating #171 cut----------
# 	tensor size 6 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.7335071982311409) > PHI
#
# -----------calculating #172 cut----------
# 	tensor size 6 with 18 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# did not cut the tensor as biased conductance (0.6949762006446969) > PHI
#
# -----------calculating #173 cut----------
# 	tensor size 6 with 12 non-zeros
# 	computing the super-spacey random surfer vector
# 	generating transition matrix: P[x]
# 	solving the egenvector problem for P[x]
# 	generating the sweep_cut
# 	calculate cuts
# -- split 6 into 3 and 3 --
#
# -----------calculating #174 cut----------
# completed recursive two-way cut

# %%
# load the openflight dic
f = readdlm("../data/openFlight/dic_openflight.txt");
wordDic = [f[i,1] => string(int(f[i,2])) for i = 1:size(f,1)];

airlineDic = Dict();
tt = open("../data/openFlight/airline.txt","r")
ss = readline(tt);
while ss!=""
    nn = sizeof(ss)
    i = 1
    while ss[i]!='#'
        i = i+1
    end
    id = ss[1:i-1]
    dec = ss[i+1:nn-1]
    airlineDic[id]=dec
    ss = readline(tt)
end


airportDic = Dict();
tt = open("../data/openFlight/airport.txt","r")
ss = readline(tt);
while ss!=""
    nn = sizeof(ss)
    i = 1
    while ss[i]!='#'
        i = i+1
    end
    id = ss[1:i-1]
    dec = ss[i+1:nn-1]
    airportDic[id]=dec
    ss = readline(tt)
end

# %%
indVec = zeros(r.n)
traCount = trav_tree(r, indVec, 1)

# print groups from start_num to end_num
# This is the europe cluster
start_num = 113; end_num = 125
countLine = 0; countPort = 0;
for i=start_num:end_num
    for j=1:539
        if indVec[j] == i
            countLine+=1
            println(airlineDic[string(wordDic[j])])
        end
    end
    for j=540:3478
        if indVec[j]==i
            countPort+=1
            println(airportDic[string(wordDic[j])])
        end
    end
end
println("Total airline is: $(countLine). Total airport is: $(countPort)")
# Out:
# ***airline 1441**:   "United Kingdom"   "bmibaby"
# ***airline 4870**:   "Tunisia"   "Tunisair"
# ***airline 220**:   "Reunion"   "Air Bourbon"
# ***airline 1463**:   "Italy"   "Blue Panorama Airlines"
# ***airline 2245**:   "Poland"   "Eurolot"
# ***airline 2681**:   "Germany"   "TUIfly"
# ***airline 4296**:   "Ireland"   "Ryanair"
# ***airline 4304**:   "Portugal"   "SATA International"
# ***airline 4897**:   "United Kingdom"   "Thomas Cook Airlines"
# ---airport 339--:     "Germany"--"Erfurt"      "Europe/Berlin"
# ---airport 341--:     "Germany"--"Munster"      "Europe/Berlin"
# ---airport 364--:     "Germany"--"Luebeck"      "Europe/Berlin"
# ---airport 441--:     "Finland"--"Lappeenranta"      "Europe/Helsinki"
# ---airport 458--:     "Finland"--"Tampere"      "Europe/Helsinki"
# ---airport 465--:     "United Kingdom"--"Belfast"      "Europe/London"
# ---airport 468--:     "United Kingdom"--"Londonderry"      "Europe/London"
# ---airport 514--:     "United Kingdom"--"Blackpool"      "Europe/London"
# ---airport 519--:     "United Kingdom"--"Hawarden"      "Europe/London"
# ---airport 520--:     "Isle of Man"--"Isle Of Man"      "Europe/Isle_of_Man"
# ---airport 540--:     "United Kingdom"--"Dundee"      "Europe/London"
# ---airport 582--:     "Netherlands"--"Maastricht"      "Europe/Amsterdam"
# ---airport 586--:     "Netherlands"--"Groningen"      "Europe/Amsterdam"
# ---airport 601--:     "Ireland"--"Kerry"      "Europe/Dublin"
# ---airport 607--:     "Denmark"--"Aarhus"      "Europe/Copenhagen"
# ---airport 645--:     "Norway"--"Haugesund"      "Europe/Oslo"
# ---airport 664--:     "Norway"--"Sandefjord"      "Europe/Oslo"
# ---airport 674--:     "Poland"--"Poznan"      "Europe/Warsaw"
# ---airport 676--:     "Poland"--"Szczecin"      "Europe/Warsaw"
# ---airport 708--:     "Sweden"--"Malmoe"      "Europe/Stockholm"
# ---airport 711--:     "Sweden"--"Vaxjo"      "Europe/Stockholm"
# ---airport 726--:     "Sweden"--"Skelleftea"      "Europe/Stockholm"
# ---airport 733--:     "Sweden"--"Vasteras"      "Europe/Stockholm"
# ---airport 1064--:     "Morocco"--"Agadir"      "Africa/Casablanca"
# ---airport 1070--:     "Morocco"--"Oujda"      "Africa/Casablanca"
# ---airport 1072--:     "Morocco"--"Rabat"      "Africa/Casablanca"
# ---airport 1080--:     "Morocco"--"Tanger"      "Africa/Casablanca"
# ---airport 1193--:     "Bulgaria"--"Plovdiv"      "Europe/Sofia"
# ---airport 1202--:     "Croatia"--"Osijek"      "Europe/Zagreb"
# ---airport 1203--:     "Croatia"--"Pula"      "Europe/Zagreb"
# ---airport 1205--:     "Croatia"--"Rijeka"      "Europe/Zagreb"
# ---airport 1213--:     "Spain"--"Almeria"      "Europe/Madrid"
# ---airport 1226--:     "Spain"--"Jerez"      "Europe/Madrid"
# ---airport 1252--:     "Spain"--"Zaragoza"      "Europe/Madrid"
# ---airport 1265--:     "France"--"Bergerac"      "Europe/Paris"
# ---airport 1268--:     "France"--"Poitiers"      "Europe/Paris"
# ---airport 1276--:     "France"--"Tarbes"      "Europe/Paris"
# ---airport 1278--:     "France"--"Brive"      "Europe/Paris"
# ---airport 1280--:     "France"--"Biarritz-bayonne"      "Europe/Paris"
# ---airport 1289--:     "France"--"Rodez"      "Europe/Paris"
# ---airport 1309--:     "France"--"Dole"      "Europe/Paris"
# ---airport 1322--:     "France"--"Calvi"      "Europe/Paris"
# ---airport 1323--:     "France"--"Figari"      "Europe/Paris"
# ---airport 1330--:     "France"--"Clermont-Ferrand"      "Europe/Paris"
# ---airport 1350--:     "France"--"St-Etienne"      "Europe/Paris"
# ---airport 1356--:     "France"--"Perpignan"      "Europe/Paris"
# ---airport 1359--:     "France"--"Montpellier"      "Europe/Paris"
# ---airport 1360--:     "France"--"Beziers"      "Europe/Paris"
# ---airport 1374--:     "France"--"Chalons"      "Europe/Paris"
# ---airport 1376--:     "France"--"Tours"      "Europe/Paris"
# ---airport 1399--:     "France"--"Lille"      "Europe/Paris"
# ---airport 1412--:     "France"--"Caen"      "Europe/Paris"
# ---airport 1418--:     "France"--"Nantes"      "Europe/Paris"
# ---airport 1435--:     "France"--"Strasbourg"      "Europe/Paris"
# ---airport 1438--:     "France"--"Hyeres"      "Europe/Paris"
# ---airport 1439--:     "France"--"Nimes"      "Europe/Paris"
# ---airport 1448--:     "Greece"--"Nea Anghialos"      "Europe/Athens"
# ---airport 1450--:     "Greece"--"Chios"      "Europe/Athens"
# ---airport 1455--:     "Greece"--"Keffallinia"      "Europe/Athens"
# ---airport 1458--:     "Greece"--"Kos"      "Europe/Athens"
# ---airport 1465--:     "Greece"--"Limnos"      "Europe/Athens"
# ---airport 1469--:     "Greece"--"Mytilini"      "Europe/Athens"
# ---airport 1488--:     "Greece"--"Zakynthos"      "Europe/Athens"
# ---airport 1505--:     "Italy"--"Pescara"      "Europe/Rome"
# ---airport 1508--:     "Italy"--"Lamezia"      "Europe/Rome"
# ---airport 1531--:     "Italy"--"Parma"      "Europe/Rome"
# ---airport 1534--:     "Italy"--"Cuneo"      "Europe/Rome"
# ---airport 1545--:     "Italy"--"Ronchi De Legionari"      "Europe/Rome"
# ---airport 1563--:     "Italy"--"Florence"      "Europe/Rome"
# ---airport 1567--:     "Italy"--"Perugia"      "Europe/Rome"
# ---airport 1582--:     "Czech Republic"--"Ostrava"      "Europe/Prague"
# ---airport 1588--:     "Czech Republic"--"Brno"      "Europe/Prague"
# ---airport 1611--:     "Austria"--"Linz"      "Europe/Vienna"
# ---airport 1629--:     "Portugal"--"Lajes (terceira Island)"      "Atlantic/Azores"
# ---airport 1645--:     "Bosnia and Herzegovina"--"Mostar"      "Europe/Sarajevo"
# ---airport 4191--:     "Greece"--"Ikaria"      "Europe/Athens"
# ---airport 4309--:     "Italy"--"Ancona"      "Europe/Rome"
# ---airport 5591--:     "Poland"--"Bydgoszcz"      "Europe/Warsaw"
# ---airport 5673--:     "Morocco"--"El Aroui"      "Africa/Casablanca"
# ---airport 6493--:     "France"--"La Rochelle"      "Europe/Paris"
# ---airport 6510--:     "Germany"--"Zweibruecken"      "Europe/Berlin"
# ---airport 8832--:     "Poland"--"Lublin"      "Europe/Warsaw"
# ---airport 9327--:     "Italy"--"Comiso"      "Europe/Rome"
# ***airline 1539**:   "Spain"   "Binter Canarias"
# ---airport 1052--:     "Spain"--"Hierro"      "Atlantic/Canary"
# ---airport 1057--:     "Spain"--"Tenerife"      "Atlantic/Canary"
# ***airline 3463**:   "Italy"   "Meridiana"
# ---airport 1520--:     "Italy"--"Olbia"      "Europe/Rome"
# ---airport 1550--:     "Italy"--"Villafranca"      "Europe/Rome"
# ***airline 240**:   "Italy"   "Air One"
# ***airline 2420**:   "Switzerland"   "Flybaboo"
# ---airport 1511--:     "Italy"--"Pantelleria"      "Europe/Rome"
# ---airport 1512--:     "Italy"--"Palermo"      "Europe/Rome"
# ***airline 2547**:   "Germany"   "Germania"
# ***airline 13757**:   "Ukraine"   "Wizz Air Ukraine"
# ---airport 373--:     "Germany"--"Dortmund"      "Europe/Berlin"
# ---airport 671--:     "Poland"--"Katowice"      "Europe/Warsaw"
# ---airport 2944--:     "Ukraine"--"Kiev"      "Europe/Kiev"
# ---airport 7821--:     "Turkey"--"Zonguldak"      "Europe/Istanbul"
# ***airline 3026**:   "United Kingdom"   "Jet2.com"
# ***airline 5013**:   "United Kingdom"   "Thomsonfly"
# ---airport 521--:     "United Kingdom"--"Newcastle"      "Europe/London"
# ---airport 534--:     "United Kingdom"--"Glasgow"      "Europe/London"
# ---airport 1198--:     "Cyprus"--"Paphos"      "Asia/Nicosia"
# ---airport 1231--:     "Spain"--"Menorca"      "Europe/Madrid"
# ---airport 1452--:     "Greece"--"Heraklion"      "Europe/Athens"
# ---airport 1472--:     "Greece"--"Rhodos"      "Europe/Athens"
# ---airport 4091--:     "Portugal"--"Funchal"      "Europe/Lisbon"
# ***airline 312**:   "Italy"   "Air Sicilia"
# ***airline 508**:   "United Kingdom"   "Aurigny Air Services"
# ***airline 2421**:   "United Kingdom"   "Flybe"
# ***airline 4438**:   "Ireland"   "Skynet Airlines"
# ---airport 488--:     "United Kingdom"--"Cardiff"      "Europe/London"
# ---airport 497--:     "Guernsey"--"Alderney"      "Europe/Guernsey"
# ---airport 498--:     "Guernsey"--"Guernsey"      "Europe/Guernsey"
# ---airport 499--:     "Jersey"--"Jersey"      "Europe/Jersey"
# ---airport 515--:     "United Kingdom"--"Humberside"      "Europe/London"
# ---airport 532--:     "United Kingdom"--"Aberdeen"      "Europe/London"
# ---airport 547--:     "United Kingdom"--"Norwich"      "Europe/London"
# ---airport 1405--:     "France"--"Dinard"      "Europe/Paris"
# ***airline 3613**:   "South Africa"   "Nationwide Airlines"
# ---airport 1264--:     "France"--"Bordeaux"      "Europe/Paris"
# ---airport 1270--:     "France"--"Limoges"      "Europe/Paris"
# ---airport 1361--:     "France"--"Avignon"      "Europe/Paris"
# ---airport 1403--:     "France"--"Brest"      "Europe/Paris"
# ---airport 1415--:     "France"--"Rennes"      "Europe/Paris"
# ***airline 151**:   "Senegal"   "Air Senegal International"
# ***airline 1203**:   "France"   "Airlinair"
# ***airline 1909**:   "France"   "Corse-Mediterranee"
# ***airline 1925**:   "Croatia"   "Croatia Airlines"
# ***airline 3776**:   "Greece"   "Olympic Airlines"
# ***airline 4965**:   "France"   "Twin Jet"
# ***airline 9818**:   "Morocco"   "Air Arabia Maroc"
# ---airport 304--:     "Belgium"--"Charleroi"      "Europe/Brussels"
# ---airport 355--:     "Germany"--"Hahn"      "Europe/Berlin"
# ---airport 467--:     "United Kingdom"--"Belfast"      "Europe/London"
# ---airport 490--:     "United Kingdom"--"Bristol"      "Europe/London"
# ---airport 491--:     "United Kingdom"--"Liverpool"      "Europe/London"
# ---airport 494--:     "United Kingdom"--"Bournemouth"      "Europe/London"
# ---airport 523--:     "United Kingdom"--"East Midlands"      "Europe/London"
# ---airport 533--:     "United Kingdom"--"Inverness"      "Europe/London"
# ---airport 537--:     "United Kingdom"--"Prestwick"      "Europe/London"
# ---airport 548--:     "United Kingdom"--"London"      "Europe/London"
# ---airport 552--:     "United Kingdom"--"Exeter"      "Europe/London"
# ---airport 585--:     "Netherlands"--"Eindhoven"      "Europe/Amsterdam"
# ---airport 596--:     "Ireland"--"Cork"      "Europe/Dublin"
# ---airport 600--:     "Ireland"--"Connaught"      "Europe/Dublin"
# ---airport 603--:     "Ireland"--"Shannon"      "Europe/Dublin"
# ---airport 657--:     "Norway"--"Rygge"      "Europe/Oslo"
# ---airport 668--:     "Poland"--"Gdansk"      "Europe/Warsaw"
# ---airport 669--:     "Poland"--"Krakow"      "Europe/Warsaw"
# ---airport 675--:     "Poland"--"Rzeszow"      "Europe/Warsaw"
# ---airport 680--:     "Poland"--"Wroclaw"      "Europe/Warsaw"
# ---airport 699--:     "Sweden"--"Stockholm"      "Europe/Stockholm"
# ---airport 1051--:     "Spain"--"Fuerteventura"      "Atlantic/Canary"
# ---airport 1055--:     "Spain"--"Las Palmas"      "Atlantic/Canary"
# ---airport 1056--:     "Spain"--"Tenerife"      "Atlantic/Canary"
# ---airport 1066--:     "Morocco"--"Fes"      "Africa/Casablanca"
# ---airport 1075--:     "Morocco"--"Marrakech"      "Africa/Casablanca"
# ---airport 1200--:     "Croatia"--"Dubrovnik"      "Europe/Zagreb"
# ---airport 1209--:     "Croatia"--"Zadar"      "Europe/Zagreb"
# ---airport 1212--:     "Spain"--"Alicante"      "Europe/Madrid"
# ---airport 1222--:     "Spain"--"Gerona"      "Europe/Madrid"
# ---airport 1227--:     "Spain"--"Murcia"      "Europe/Madrid"
# ---airport 1236--:     "Spain"--"Reus"      "Europe/Madrid"
# ---airport 1251--:     "Spain"--"Santander"      "Europe/Madrid"
# ---airport 1253--:     "Spain"--"Sevilla"      "Europe/Madrid"
# ---airport 1279--:     "France"--"Perigueux"      "Europe/Paris"
# ---airport 1321--:     "France"--"Bastia"      "Europe/Paris"
# ---airport 1324--:     "France"--"Ajaccio"      "Europe/Paris"
# ---airport 1352--:     "France"--"Carcassonne"      "Europe/Paris"
# ---airport 1367--:     "France"--"Beauvais"      "Europe/Paris"
# ---airport 1454--:     "Greece"--"Kithira"      "Europe/Athens"
# ---airport 1459--:     "Greece"--"Karpathos"      "Europe/Athens"
# ---airport 1473--:     "Greece"--"Patras"      "Europe/Athens"
# ---airport 1474--:     "Greece"--"Chania"      "Europe/Athens"
# ---airport 1476--:     "Greece"--"Samos"      "Europe/Athens"
# ---airport 1501--:     "Italy"--"Bari"      "Europe/Rome"
# ---airport 1506--:     "Italy"--"Brindisi"      "Europe/Rome"
# ---airport 1515--:     "Italy"--"Trapani"      "Europe/Rome"
# ---airport 1517--:     "Italy"--"Alghero"      "Europe/Rome"
# ---airport 1519--:     "Italy"--"Cagliari"      "Europe/Rome"
# ---airport 1525--:     "Italy"--"Bergamo"      "Europe/Rome"
# ---airport 1539--:     "Italy"--"Treviso"      "Europe/Rome"
# ---airport 1553--:     "Italy"--"Rome"      "Europe/Rome"
# ---airport 1562--:     "Italy"--"Pisa"      "Europe/Rome"
# ---airport 1626--:     "Portugal"--"Faro"      "Europe/Lisbon"
# ---airport 1636--:     "Portugal"--"Porto"      "Europe/Lisbon"
# ---airport 1745--:     "Slovakia"--"Bratislava"      "Europe/Bratislava"
# ---airport 3956--:     "Lithuania"--"Kaunas"      "Europe/Vilnius"
# ---airport 3986--:     "Germany"--"Memmingen"      "Europe/Berlin"
# ---airport 4166--:     "Germany"--"Karlsruhe/Baden-Baden"      "Europe/Berlin"
# ---airport 4192--:     "Greece"--"Kalymnos"      "Europe/Athens"
# ---airport 4196--:     "Greece"--"Kastelorizo"      "Europe/Athens"
# ---airport 4198--:     "Germany"--"Weeze"      "Europe/Berlin"
# ---airport 5562--:     "United Kingdom"--"Doncaster, Sheffield"      "Europe/London"
# ---airport 7447--:     "Tunisia"--"Enfidha"      "Africa/Tunis"
# ---airport 8414--:     "Poland"--"Warsaw"      "Europe/Warsaw"
# ***airline 1492**:   "United States"   "Big Sky Airlines"
# ---airport 1460--:     "Greece"--"Kerkyra/corfu"      "Europe/Athens"
# ---airport 1470--:     "Greece"--"Preveza"      "Europe/Athens"
# ***airline 2585**:   "Sweden"   "Golden Air"
# ---airport 691--:     "Sweden"--"Gothenborg"      "Europe/Stockholm"
# ---airport 746--:     "Sweden"--"Visby"      "Europe/Stockholm"
# ***airline 2117**:   "United Kingdom"   "Eastern Airways"
# ---airport 495--:     "United Kingdom"--"Southampton"      "Europe/London"
# ---airport 517--:     "United Kingdom"--"Leeds"      "Europe/London"
# Total airline is: 32. Total airport is: 184

# %%
# This is the US cluster
start_num = 108; end_num = 112
countLine = 0; countPort = 0;
for i=start_num:end_num
    for j=1:539
        if indVec[j] == i
            countLine+=1
            println(airlineDic[string(wordDic[j])])
        end
    end
    for j=540:3478
        if indVec[j]==i
            countPort+=1
            println(airportDic[string(wordDic[j])])
        end
    end
end
println("Total airline is: $(countLine). Total airport is: $(countPort)")
# Out:
# ***airline 2607**:   "United States"   "Great Lakes Airlines"
# ***airline 35**:   "United States"   "Allegiant Air"
# ***airline 1316**:   "United States"   "AirTran Airways"
# ***airline 2468**:   "United States"   "Frontier Airlines"
# ***airline 3976**:   "United States"   "Pinnacle Airlines"
# ---airport 3454--:     "United States"--"Omaha"      "America/Chicago"
# ---airport 3457--:     "United States"--"Wichita"      "America/Chicago"
# ---airport 3463--:     "United States"--"Bangor"      "America/New_York"
# ---airport 3473--:     "United States"--"Memphis"      "America/Chicago"
# ---airport 3486--:     "United States"--"Cleveland"      "America/New_York"
# ---airport 3520--:     "United States"--"Washington"      "America/New_York"
# ---airport 3578--:     "United States"--"Chattanooga"      "America/New_York"
# ---airport 3598--:     "United States"--"Duluth"      "America/Chicago"
# ---airport 3609--:     "United States"--"Shreveport"      "America/Chicago"
# ---airport 3622--:     "United States"--"Rochester"      "America/New_York"
# ---airport 3627--:     "United States"--"Dayton"      "America/New_York"
# ---airport 3636--:     "United States"--"Tucson"      "America/Phoenix"
# ---airport 3641--:     "United States"--"Providence"      "America/New_York"
# ---airport 3652--:     "United States"--"Midland"      "America/Chicago"
# ---airport 3660--:     "United States"--"Little Rock"      "America/Chicago"
# ---airport 3674--:     "United States"--"Columbus"      "America/New_York"
# ---airport 3685--:     "United States"--"Grand Rapids"      "America/New_York"
# ---airport 3691--:     "United States"--"Laredo"      "America/Chicago"
# ---airport 3729--:     "United States"--"Des Moines"      "America/Chicago"
# ---airport 3752--:     "United States"--"Philadelphia"      "America/New_York"
# ---airport 3771--:     "United States"--"Plattsburgh"      "America/New_York"
# ---airport 3777--:     "United States"--"Bellingham"      "America/Los_Angeles"
# ---airport 3805--:     "United States"--"Stockton"      "America/Los_Angeles"
# ---airport 3806--:     "United States"--"Charleston"      "America/New_York"
# ---airport 3811--:     "United States"--"Birmingham"      "America/Chicago"
# ---airport 3819--:     "United States"--"Colorado Springs"      "America/Denver"
# ---airport 3820--:     "United States"--"Buffalo"      "America/New_York"
# ---airport 3825--:     "United States"--"Windsor Locks"      "America/New_York"
# ---airport 3826--:     "United States"--"Mcallen"      "America/Chicago"
# ---airport 3840--:     "United States"--"Amarillo"      "America/Chicago"
# ---airport 3855--:     "United States"--"Tulsa"      "America/Chicago"
# ---airport 3857--:     "United States"--"Islip"      "America/New_York"
# ---airport 3858--:     "United States"--"Minneapolis"      "America/Chicago"
# ---airport 3863--:     "United States"--"Oklahoma City"      "America/Chicago"
# ---airport 3867--:     "United States"--"Santa Ana"      "America/Los_Angeles"
# ---airport 3872--:     "United States"--"Casper"      "America/Denver"
# ---airport 3880--:     "United States"--"Great Falls"      "America/Denver"
# ---airport 3946--:     "United States"--"Elmira"      "America/New_York"
# ---airport 3948--:     "United States"--"Monterey"      "America/Los_Angeles"
# ---airport 4011--:     "United States"--"Manchester NH"      "America/New_York"
# ---airport 4016--:     "United States"--"Roanoke VA"      "America/New_York"
# ---airport 4020--:     "United States"--"Bozeman"      "America/Denver"
# ---airport 4021--:     "United States"--"Billings"      "America/Denver"
# ---airport 4034--:     "United States"--"Greenville"      "America/New_York"
# ---airport 4040--:     "United States"--"Toledo"      "America/New_York"
# ---airport 4063--:     "United States"--"Grand Junction"      "America/Denver"
# ---airport 4087--:     "United States"--"Rapid City"      "America/Denver"
# ---airport 4089--:     "United States"--"Flint"      "America/New_York"
# ---airport 4100--:     "United States"--"Idaho Falls"      "America/Denver"
# ---airport 4116--:     "United States"--"BRISTOL"      "America/New_York"
# ---airport 4127--:     "United States"--"Kalispell"      "America/Denver"
# ---airport 4216--:     "United States"--"Missoula"      "America/Denver"
# ---airport 4336--:     "United States"--"Springfield"      "America/Chicago"
# ---airport 4356--:     "United States"--"Bentonville"      "America/Chicago"
# ---airport 5740--:     "United States"--"Grand Island"      "America/Chicago"
# ---airport 5742--:     "United States"--"Huntington"      "America/New_York"
# ---airport 5758--:     "United States"--"Owensboro"      "America/Chicago"
# ---airport 5772--:     "United States"--"Santa Maria"      "America/Los_Angeles"
# ---airport 6133--:     "United States"--"Pasco"      "America/Los_Angeles"
# ---airport 6962--:     "United States"--"Branson"      "America/Chicago"
# ***airline 1629**:   "United States"   "Cape Air"
# ***airline 4547**:   "United States"   "Southwest Airlines"
# ***airline 4687**:   "United States"   "Spirit Airlines"
# ---airport 3448--:     "United States"--"Boston"      "America/New_York"
# ---airport 3467--:     "United States"--"Spokane"      "America/Los_Angeles"
# ---airport 3495--:     "United States"--"Boise"      "America/Denver"
# ---airport 3536--:     "United States"--"Salt Lake City"      "America/Denver"
# ---airport 3577--:     "United States"--"Seattle"      "America/Los_Angeles"
# ---airport 3645--:     "United States"--"Detroit"      "America/New_York"
# ---airport 3697--:     "United States"--"New York"      "America/New_York"
# ---airport 3720--:     "United States"--"Portland"      "America/Los_Angeles"
# ---airport 3807--:     "United States"--"Reno"      "America/Los_Angeles"
# ---airport 3864--:     "United States"--"Albany"      "America/New_York"
# ---airport 1852--:     "Mexico"--"Cancun"      "America/Mexico_City"
# ---airport 3442--:     "United States"--"Grand Forks"      "America/Chicago"
# ---airport 3447--:     "United States"--"Trenton"      "America/New_York"
# ---airport 3453--:     "United States"--"Oakland"      "America/Los_Angeles"
# ---airport 3458--:     "United States"--"Kansas City"      "America/Chicago"
# ---airport 3462--:     "United States"--"Phoenix"      "America/Phoenix"
# ---airport 3488--:     "United States"--"Cincinnati"      "America/New_York"
# ---airport 3498--:     "United States"--"Minot"      "America/Chicago"
# ---airport 3502--:     "United States"--"Dallas"      "America/Chicago"
# ---airport 3515--:     "United States"--"Myrtle Beach"      "America/New_York"
# ---airport 3533--:     "United States"--"Fort Lauderdale"      "America/New_York"
# ---airport 3542--:     "United States"--"Harrisburg"      "America/New_York"
# ---airport 3559--:     "United States"--"El Paso"      "America/Denver"
# ---airport 3566--:     "United States"--"Houston"      "America/Chicago"
# ---airport 3570--:     "United States"--"Pittsburgh"      "America/New_York"
# ---airport 3585--:     "United States"--"Indianapolis"      "America/New_York"
# ---airport 3617--:     "United States"--"St. Petersburg"      "America/New_York"
# ---airport 3621--:     "United States"--"San Antonio"      "America/Chicago"
# ---airport 3626--:     "United States"--"Raleigh-durham"      "America/New_York"
# ---airport 3630--:     "United States"--"Niagara Falls"      "America/New_York"
# ---airport 3633--:     "United States"--"Newport News"      "America/New_York"
# ---airport 3644--:     "United States"--"Burbank"      "America/Los_Angeles"
# ---airport 3646--:     "United States"--"Tampa"      "America/New_York"
# ---airport 3673--:     "United States"--"Austin"      "America/Chicago"
# ---airport 3676--:     "United States"--"Knoxville"      "America/New_York"
# ---airport 3678--:     "United States"--"St. Louis"      "America/Chicago"
# ---airport 3682--:     "United States"--"Atlanta"      "America/New_York"
# ---airport 3687--:     "United States"--"Fresno"      "America/Los_Angeles"
# ---airport 3690--:     "United States"--"Nashville"      "America/Chicago"
# ---airport 3712--:     "United States"--"Jacksonville"      "America/New_York"
# ---airport 3717--:     "United States"--"Milwaukee"      "America/Chicago"
# ---airport 3734--:     "United States"--"Ontario"      "America/Los_Angeles"
# ---airport 3747--:     "United States"--"Chicago"      "America/Chicago"
# ---airport 3748--:     "United States"--"San Jose"      "America/Los_Angeles"
# ---airport 3751--:     "United States"--"Denver"      "America/Denver"
# ---airport 3759--:     "United States"--"Columbus"      "America/New_York"
# ---airport 3793--:     "United States"--"Fort Myers"      "America/New_York"
# ---airport 3817--:     "United States"--"Sacramento"      "America/Los_Angeles"
# ---airport 3849--:     "United States"--"Baltimore"      "America/New_York"
# ---airport 3859--:     "United States"--"Wilmington"      "America/New_York"
# ---airport 3861--:     "United States"--"New Orleans"      "America/Chicago"
# ---airport 3877--:     "United States"--"Las Vegas"      "America/Los_Angeles"
# ---airport 3881--:     "United States"--"Youngstown"      "America/New_York"
# ---airport 4007--:     "United States"--"Asheville"      "America/New_York"
# ---airport 4008--:     "United States"--"Greensboro"      "America/New_York"
# ---airport 4009--:     "United States"--"Sioux Falls"      "America/Chicago"
# ---airport 4014--:     "United States"--"Louisville"      "America/New_York"
# ---airport 4017--:     "United States"--"Lexington KY"      "America/New_York"
# ---airport 4019--:     "United States"--"Albuquerque"      "America/Denver"
# ---airport 4028--:     "United States"--"Rockford"      "America/Chicago"
# ---airport 4037--:     "United States"--"Bloomington"      "America/Chicago"
# ---airport 4041--:     "United States"--"Fort Wayne"      "America/New_York"
# ---airport 4043--:     "United States"--"Cedar Rapids"      "America/Chicago"
# ---airport 4046--:     "United States"--"Peoria"      "America/Chicago"
# ---airport 4047--:     "United States"--"Appleton"      "America/Chicago"
# ---airport 4072--:     "United States"--"Moline"      "America/Chicago"
# ---airport 4083--:     "United States"--"Bismarck"      "America/Chicago"
# ---airport 4099--:     "United States"--"Eugene"      "America/Los_Angeles"
# ---airport 4167--:     "United States"--"Sanford"      "America/New_York"
# ---airport 4292--:     "United States"--"Fargo"      "America/Chicago"
# ---airport 4348--:     "United States"--"Springfield"      "America/Chicago"
# ---airport 4355--:     "United States"--"Allentown"      "America/New_York"
# ---airport 4359--:     "United States"--"South Bend"      "America/New_York"
# ---airport 6505--:     "United States"--"Mesa"      "America/Phoenix"
# ---airport 7056--:     "United States"--"Punta Gorda"      "America/New_York"
# ***airline 439**:   "ALASKA"   "Alaska Airlines"
# ---airport 3731--:     "United States"--"San Diego"      "America/Los_Angeles"
# ---airport 3878--:     "United States"--"Orlando"      "America/New_York"
# Total airline is: 9. Total airport is: 137

# %%
# output the clsutering result for matlab plot
